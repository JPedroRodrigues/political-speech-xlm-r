# %% [markdown]
# # Análise Exploratória dos Dados - Dataset de Discursos Parlamentares sobre o Tema Posse e Porte de Armas de Fogo (2023 - 2025)
# |Nome | RA |
# | --- | --- |
# | João Pedro Rodrigues Vieira | 10403595 |

# %% [markdown]
# ## Sobre o Conteúdo
# É apresentada uma leitura de informações pertinentes ao dataset construído por meio do pipeline. Aqui, serão encontradas contabilizações que ajudam a visualizar a dimensionalidade dos discursos coletados, como a quantidade de partidos diferentes por discurso, como também em quais partidos e espectros políticos os deputados oradores estão situados.
#
# ### Histórico de Atualizações
# - (28/09/2025) João Pedro R. Vieira: adicionar breve análise do conteúdo extraído.

# %%
import json;
import pandas as pd;
import seaborn as sns;
import matplotlib.pyplot as plt;

# %%
## 2. Leitura dos Datasets
def load_json(file_path):
    """
    Função para carregar um arquivo JSON e retornar os dados como um dicionário.
    Args:
        file_path (str): Caminho para o arquivo JSON.
    Returns:
        dict: Dados carregados do arquivo JSON.
    """
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file);
    return data;

# %%
# Lista de textos em português
data = load_json("discursos-armamento-2023-2025.json");
df = pd.DataFrame(data["data"]);
df.head()
# Out:
#                              idDiscurso  idEvento  descricaoTipoEvento  \
# 0  aa6dddcd-b4d4-4c09-b401-3c23b1a100c2     71506  Sessão Deliberativa
# 1  0bbb5797-9b23-4ec4-82a4-b9cd5987296a     71506  Sessão Deliberativa
# 2  b2072414-fa5a-4b5b-a7b1-c26c1efdecff     71506  Sessão Deliberativa
# 3  f5257f2f-b51c-4cb7-bdb0-696df39f0180     71506  Sessão Deliberativa
# 4  f5257f2f-b51c-4cb7-bdb0-696df39f0180     71506  Sessão Deliberativa
#
#    idDeputado       nomeDeputado  \
# 0       73579      Alberto Fraga
# 1       74171      Chico Alencar
# 2      156190  Marcel van Hattem
# 3      160575        Erika Kokay
# 4      160575        Erika Kokay
#
#                                          uriDeputado siglaUf  idLegislatura  \
# 0  https://dadosabertos.camara.leg.br/api/v2/depu...      DF             57
# 1  https://dadosabertos.camara.leg.br/api/v2/depu...      RJ             57
# 2  https://dadosabertos.camara.leg.br/api/v2/depu...      RS             57
# 3  https://dadosabertos.camara.leg.br/api/v2/depu...      DF             57
# 4  https://dadosabertos.camara.leg.br/api/v2/depu...      DF             57
#
#   siglaPartido                                         uriPartido  \
# 0           PL  https://dadosabertos.camara.leg.br/api/v2/part...
# 1         PSOL  https://dadosabertos.camara.leg.br/api/v2/part...
# 2         Novo  https://dadosabertos.camara.leg.br/api/v2/part...
# 3           PT  https://dadosabertos.camara.leg.br/api/v2/part...
# 4           PT  https://dadosabertos.camara.leg.br/api/v2/part...
#
#           tipoDiscurso           faseEvento    dataHoraInicio  \
# 0  BREVES COMUNICAÇÕES  Breves Comunicações  2023-12-06T16:44
# 1           PELA ORDEM         Ordem do Dia  2023-12-06T22:40
# 2           COMO LÍDER         Ordem do Dia  2023-12-06T23:28
# 3           PELA ORDEM         Ordem do Dia  2023-12-06T22:52
# 4           PELA ORDEM         Ordem do Dia  2023-12-06T22:24
#
#                                             keywords  \
# 0  Tráfico internacional de arma de fogo,Polícia ...
# 1  Federação PSOL REDE,favorável,Estatuto do Desa...
# 2  Requerimento de urgência,Projeto de decreto le...
# 3  Governo,Presidente da República,redução,Assass...
# 4  Projeto de decreto legislativo,sustação,Decret...
#
#                                              sumario  \
# 0  O Deputado elogiou a Operação Dakovo, que desm...
# 1  O Deputado, em nome da Federação PSOL REDE, re...
# 2  O Deputado expressou sua insatisfação pela der...
# 3  A Deputada enfatizou a importância da verdade ...
# 4  A Deputada manifestou sua preocupação com a te...
#
#                                          transcricao espectro_politico  \
# 0  O SR. ALBERTO FRAGA (PL - DF. Sem revisão do o...    Centro-direita
# 1  O SR. CHICO ALENCAR (Bloco/PSOL - RJ. Pela ord...          Esquerda
# 2  O SR. MARCEL VAN HATTEM (NOVO - RS. Como Líder...           Direita
# 3  A SRA. ERIKA KOKAY (Bloco/PT - DF. Pela ordem....          Esquerda
# 4  A SRA. ERIKA KOKAY (Bloco/PT - DF. Pela ordem....          Esquerda
#
#   posicionamento_ideologico
# 0               Conservador
# 1              Progressista
# 2               Conservador
# 3              Progressista
# 4              Progressista

# %%
print("Neste dataset, foram extraídas as seguintes informações:");

speeches_count = df["idDiscurso"].count();
print(f"Quantidade de discursos: {speeches_count}");

parties_count = df["siglaPartido"].nunique();
print(f"Quantidade de partidos diferentes: {parties_count}");

political_spectrum_count = df["espectro_politico"].nunique();
print(f"Quantidade de espectros políticos diferentes: {political_spectrum_count}");

ideological_position_count = df["posicionamento_ideologico"].nunique();
print(f"Quantidade de posicionamentos ideológicos diferentes: {ideological_position_count}");
# Out:
# Neste dataset, foram extraídas as seguintes informações:
# Quantidade de discursos: 55
# Quantidade de partidos diferentes: 10
# Quantidade de espectros políticos diferentes: 4
# Quantidade de posicionamentos ideológicos diferentes: 3

# %%
sns.displot(data=df, x="espectro_politico", hue="posicionamento_ideologico", multiple="stack");
plt.title("Distribuição dos discursos por espectro político e posicionamento ideológico");
plt.xlabel("Espectro Político");
plt.ylabel("Quantidade de Discursos");
plt.xticks(rotation=45);
plt.show();

# %%
sns.displot(data=df, x="espectro_politico", hue="siglaPartido", multiple="stack");
plt.title("Distribuição dos discursos por espectro político e sigla partidária");
plt.xlabel("Espectro Político");
plt.ylabel("Quantidade de Discursos");
plt.xticks(rotation=45);
plt.show();
